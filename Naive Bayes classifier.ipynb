# %% [markdown]
# ##  **NAIVE BAYES CLASSIFIER**

# %% [markdown]
# ## 1.  Question
#
#
# ### a) Specifying the Data Analytic Question
#
# ### b)  Metrics of Success
#
# * Sucessful Exploratory Data Analysis.
# * Sucessful feature engineering.
# * Sucessful check for multicollinearity.
# * Sucessful generation of a K-Nearest Neighbours (KNN) Classifier model .
# * Sucessful optimization of model parameters.
# * Sucessful Computation of accuracy score on all models.
# * Sucessful selection of the prefered model.
# ### c) Understanding the context
#
# ### d) Experimental Design
# * Formulation of the research question.
# * Loading the data.
# * Exploratory Data Analysis.
# * feature engineering.
# * Multicollinearity check.
# * KNN model generation.
# * Model Parameter optimization and plots.
# * Challenging the solution.
# * Follow up .
# ### e) Data Relevance

# %% [markdown]
# #2. Importing required libraries

# %%
# %matplotlib inline
import warnings
import sklearn
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 3. Reading the Data

# %% [markdown]
# Loading the Data from the source i.e. csv

# %%
spambase_names= pd.read_csv('spambase_names.csv')

# %%
names = spambase_names['Column_Name']

# %% [markdown]
#  Assign colum names to the dataset and to pandas dataframe

# %%
spambase_data= pd.read_csv('spambase_data.csv', names = names)
spambase_data.head(2)
# Out:
#    word_freq_make  ...  spam_non_spam_classes
# 0            0.00  ...                      1
# 1            0.21  ...                      1
#
# [2 rows x 58 columns]

# %% [markdown]
# ##Gaussian Naive Bayes Classifier

# %% [markdown]
# ##Splitting the data into a training set and a test set

# %% [markdown]
# #A: Classification (split:80-20)

# %%
X = spambase_data.drop('spam_non_spam_classes',1)
y = spambase_data['spam_non_spam_classes']

# Splitting our data into a training set and a test set
# 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=6)

# %% [markdown]
# Training the model

# %%
clf = GaussianNB()  
model = clf.fit(X_train, y_train)

# %% [markdown]
# Prediction on test data

# %%
predicted = model.predict(X_test)

# %% [markdown]
# Model Accuracy

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print('\n',"*"*100)
print(" Model Accuracy:",metrics.accuracy_score(y_test, predicted)*100,'%')
print('\n',"*"*100)
# Out:
#  ****************************************************************************************************
#  Model Accuracy: 81.54180238870794 %
#
#  ****************************************************************************************************

# %% [markdown]
# confusion_matrix

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test, predicted)
mat
# Out:
# array([[403, 156],
#        [ 14, 348]])

# %% [markdown]
# #B: Classification (split:70-30)

# %%
# Splitting our data into a training set and a test set
# 
X_trainb, X_testb, y_trainb, y_testb = train_test_split(X, y, test_size=0.3, random_state=6)

# %%
clfb = GaussianNB()  
modelb = clfb.fit(X_trainb, y_trainb)

# %%
predictedb = modelb.predict(X_testb)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print('\n',"*"*100)
print(" Model Accuracy:",metrics.accuracy_score(y_testb, predictedb)*100,'%')
print('\n',"*"*100)
# Out:
#  ****************************************************************************************************
#  Model Accuracy: 82.33164373642288 %
#
#  ****************************************************************************************************

# %% [markdown]
# #C : Classification (split:60-40)

# %%
# Splitting our data into a training set and a test set
# 
X_trainc, X_testc, y_trainc, y_testc = train_test_split(X, y, test_size=0.4, random_state=6)

# %%
clfc= GaussianNB()  
modelc = clfc.fit(X_trainc, y_trainc)

# %%
# Model Accuracy, how often is the classifier correct?
predictedc = modelc.predict(X_testc)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print('\n',"*"*100)
print(" Model Accuracy:",metrics.accuracy_score(y_testc, predictedc)*100,'%')
print('\n',"*"*100)
# Out:
#  ****************************************************************************************************
#  Model Accuracy: 82.88973384030417 %
#
#  ****************************************************************************************************

# %% [markdown]
# #Outcomes of the various classifications

# %%
print('\n',"*"*100)
print('\n',"Model Accuracy for  (80-20)split::",metrics.accuracy_score(y_test, predicted)*100,'%')
print('\n',"Model Accuracy for  (70-30)split::",metrics.accuracy_score(y_testb, predictedb)*100,'%')
print('\n',"Model Accuracy for  (60-40)split::",metrics.accuracy_score(y_testc, predictedc)*100,'%')
print('\n',"*"*100)
# Out:
#  ****************************************************************************************************
#
#  Model Accuracy for  (80-20)split:: 81.54180238870794 %
#
#  Model Accuracy for  (70-30)split:: 82.33164373642288 %
#
#  Model Accuracy for  (60-40)split:: 82.88973384030417 %
#
#  ****************************************************************************************************

# %% [markdown]
# Notably a lager training dataset doesn't grantee  better model performance.

# %% [markdown]
# ##Naive Bayes Classifier - Model Optimization

# %% [markdown]
# Remove Correlated Features

# %%
import seaborn as sns

# calculate the correlations
correlations = spambase_data.corr()

correlations
# Out:
#                             word_freq_make  ...  spam_non_spam_classes
# word_freq_make                    1.000000  ...               0.126208
# word_freq_address                -0.016759  ...              -0.030224
# word_freq_all                     0.065627  ...               0.196988
# word_freq_3d                      0.013273  ...               0.057371
# word_freq_our                     0.023119  ...               0.241920
# word_freq_over                    0.059674  ...               0.232604
# word_freq_remove                  0.007669  ...               0.332117
# word_freq_internet               -0.003950  ...               0.206808
# word_freq_order                   0.106263  ...               0.231551
# word_freq_mail                    0.041198  ...               0.138962
# word_freq_receive                 0.188459  ...               0.234529
# word_freq_will                    0.105801  ...               0.007741
# ...

# %% [markdown]
# # plot the heatmap

# %%
# plot the heatmap 
sns.heatmap(correlations, xticklabels=correlations.columns, yticklabels=correlations.columns, annot=True).plot(figsize= (50,50))

# %%
# plot the clustermap 
sns.clustermap(correlations, xticklabels=correlations.columns, yticklabels=correlations.columns, annot=True)

# %% [markdown]
# #Hyperparameter Tuning With Bayesian Optimization

# %%
# example of bayesian optimization with scikit-optimize
from numpy import mean
from sklearn.datasets import make_blobs
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
# !pip  install scikit_optimize
from skopt.space import Integer
from skopt.utils import use_named_args
from skopt import gp_minimize
 

X = spambase_data.drop('spam_non_spam_classes',1)
y = spambase_data['spam_non_spam_classes']

# Splitting our data into a training set and a test set
# 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=6) 
# define the model
model = KNeighborsClassifier()
# define the space of hyperparameters to search
search_space = [Integer(1, 5, name='n_neighbors'), Integer(1, 2, name='p')]
 
# define the function used to evaluate a given configuration
@use_named_args(search_space)
def evaluate_model(**params):
	# something
	model.set_params(**params)
	# calculate 5-fold cross validation
	result = cross_val_score(model, X, y, cv=5, n_jobs=-1, scoring='accuracy')
	# calculate the mean of the scores
	estimate = mean(result)
	return 1.0 - estimate
 
# perform optimization
result = gp_minimize(evaluate_model, search_space)

# plot all samples and the final surrogate function

# %% [markdown]
# # summarizing finding:

# %%
print('\n',"*"*100)
print('\n','Best Parameters: n_neighbors=%d, p=%d' % (result.x[0], result.x[1]))
print('\n','Best Accuracy: %.3f' % (1.0 - result.fun))
print('\n',"*"*100)
# Out:
#  ****************************************************************************************************
#
#  Best Parameters: n_neighbors=1, p=1
#
#  Best Accuracy: 0.805
#
#  ****************************************************************************************************

# %% [markdown]
# ##Challenging the solution
#
# The models performance can be improved through other advanced machine learning techniques.

# %% [markdown]
# ### a). Did we have the right data?
# *  yes
#
#
# ### b). Do we need other data to answer our question?
#
# * Probally yes because theremight be other factors influencethe outcome.
#
# ### c). Did we have the right question?
#
# * Open for further research.
